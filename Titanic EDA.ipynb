# %%
# !pip install Pyforest
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for Pyforest: filename=pyforest-1.1.0-py2.py3-none-any.whl size=14630 sha256=6ab217e22a61284c4d214c346a49433c3da92b68bfbf75b80e9f62cc082d4ee8
#   Stored in directory: c:\users\vanaja\appdata\local\pip\cache\wheels\ec\0b\21\11e15b81d41c6ea60c8c26a49c885f75abd45bfa0456ef4ba7
# Successfully built Pyforest
# ...

# %%
# !pip install numpy
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
titanic=pd.read_csv("C:\\Users\\Vanaja\\Documents\\Tested.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# !pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.6 kB 326.8 kB/s eta 0:00:01
#      -------------------------------------- 60.6/60.6 kB 402.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.9 MB 3.2 MB/s eta 0:00:04
#     --------------------------------------- 0.2/10.9 MB 2.6 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/10.9 MB 2.6 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/10.9 MB 3.0 MB/s eta 0:00:04
#    --- ------------------------------------ 0.9/10.9 MB 4.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/10.9 MB 5.1 MB/s eta 0:00:02
# ...

# %%
# import label encoder.
from sklearn import preprocessing

# label-encoder object knows how to understand word labels.
label_encoder=preprocessing.LabelEncoder()

# Encode labels in column "Gender".
# Converting Male as "1" and Female as "0".

titanic['Sex']=label_encoder.fit_transform(titanic['Sex'])
titanic['Sex'].value_counts()
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    1  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)    0  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                                Wirz, Mr. Albert    1  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# ...

# %%
a=titanic.drop('Name', axis=1)
a
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  \
# 0            892         0       3    1  34.5      0      0
# 1            893         1       3    0  47.0      1      0
# 2            894         0       2    1  62.0      0      0
# 3            895         0       3    1  27.0      0      0
# 4            896         1       3    0  22.0      1      1
# ..           ...       ...     ...  ...   ...    ...    ...
# 413         1305         0       3    1   NaN      0      0
# 414         1306         1       1    0  39.0      0      0
# 415         1307         0       3    1  38.5      0      0
# 416         1308         0       3    1   NaN      0      0
# 417         1309         0       3    1   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# ...

# %%
b=a.drop('SibSp', axis=1)
b
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  Parch              Ticket  \
# 0            892         0       3    1  34.5      0              330911
# 1            893         1       3    0  47.0      0              363272
# 2            894         0       2    1  62.0      0              240276
# 3            895         0       3    1  27.0      0              315154
# 4            896         1       3    0  22.0      1             3101298
# ..           ...       ...     ...  ...   ...    ...                 ...
# 413         1305         0       3    1   NaN      0           A.5. 3236
# 414         1306         1       1    0  39.0      0            PC 17758
# 415         1307         0       3    1  38.5      0  SOTON/O.Q. 3101262
# 416         1308         0       3    1   NaN      0              359309
# 417         1309         0       3    1   NaN      1                2668
#
#          Fare Cabin Embarked
# 0      7.8292   NaN        Q
# 1      7.0000   NaN        S
# ...

# %%
c=b.drop('Parch', axis=1)
c
# Out:
#      PassengerId  Survived  Pclass  Sex   Age              Ticket      Fare  \
# 0            892         0       3    1  34.5              330911    7.8292
# 1            893         1       3    0  47.0              363272    7.0000
# 2            894         0       2    1  62.0              240276    9.6875
# 3            895         0       3    1  27.0              315154    8.6625
# 4            896         1       3    0  22.0             3101298   12.2875
# ..           ...       ...     ...  ...   ...                 ...       ...
# 413         1305         0       3    1   NaN           A.5. 3236    8.0500
# 414         1306         1       1    0  39.0            PC 17758  108.9000
# 415         1307         0       3    1  38.5  SOTON/O.Q. 3101262    7.2500
# 416         1308         0       3    1   NaN              359309    8.0500
# 417         1309         0       3    1   NaN                2668   22.3583
#
#     Cabin Embarked
# 0     NaN        Q
# ...

# %%
d=c.drop('Fare', axis=1)
d
# Out:
#      PassengerId  Survived  Pclass  Sex   Age              Ticket Cabin  \
# 0            892         0       3    1  34.5              330911   NaN
# 1            893         1       3    0  47.0              363272   NaN
# 2            894         0       2    1  62.0              240276   NaN
# 3            895         0       3    1  27.0              315154   NaN
# 4            896         1       3    0  22.0             3101298   NaN
# ..           ...       ...     ...  ...   ...                 ...   ...
# 413         1305         0       3    1   NaN           A.5. 3236   NaN
# 414         1306         1       1    0  39.0            PC 17758  C105
# 415         1307         0       3    1  38.5  SOTON/O.Q. 3101262   NaN
# 416         1308         0       3    1   NaN              359309   NaN
# 417         1309         0       3    1   NaN                2668   NaN
#
#     Embarked
# 0          Q
# 1          S
# 2          Q
# 3          S
# 4          S
# ..       ...
# ...

# %%
e=d.drop('Ticket', axis=1)
e
# Out:
#      PassengerId  Survived  Pclass  Sex   Age Cabin Embarked
# 0            892         0       3    1  34.5   NaN        Q
# 1            893         1       3    0  47.0   NaN        S
# 2            894         0       2    1  62.0   NaN        Q
# 3            895         0       3    1  27.0   NaN        S
# 4            896         1       3    0  22.0   NaN        S
# ..           ...       ...     ...  ...   ...   ...      ...
# 413         1305         0       3    1   NaN   NaN        S
# 414         1306         1       1    0  39.0  C105        C
# 415         1307         0       3    1  38.5   NaN        S
# 416         1308         0       3    1   NaN   NaN        S
# 417         1309         0       3    1   NaN   NaN        C
#
# [418 rows x 7 columns]

# %%
Titanic=e.drop('Cabin', axis=1)
Titanic
# Out:
#      PassengerId  Survived  Pclass  Sex   Age Embarked
# 0            892         0       3    1  34.5        Q
# 1            893         1       3    0  47.0        S
# 2            894         0       2    1  62.0        Q
# 3            895         0       3    1  27.0        S
# 4            896         1       3    0  22.0        S
# ..           ...       ...     ...  ...   ...      ...
# 413         1305         0       3    1   NaN        S
# 414         1306         1       1    0  39.0        C
# 415         1307         0       3    1  38.5        S
# 416         1308         0       3    1   NaN        S
# 417         1309         0       3    1   NaN        C
#
# [418 rows x 6 columns]

# %%
Titanic['Age'].mean()
# Out:
# 30.272590361445783

# %%
Titanic['Age']=Titanic['Age'].fillna(value=30)
Titanic
# Out:
#      PassengerId  Survived  Pclass  Sex   Age Embarked
# 0            892         0       3    1  34.5        Q
# 1            893         1       3    0  47.0        S
# 2            894         0       2    1  62.0        Q
# 3            895         0       3    1  27.0        S
# 4            896         1       3    0  22.0        S
# ..           ...       ...     ...  ...   ...      ...
# 413         1305         0       3    1  30.0        S
# 414         1306         1       1    0  39.0        C
# 415         1307         0       3    1  38.5        S
# 416         1308         0       3    1  30.0        S
# 417         1309         0       3    1  30.0        C
#
# [418 rows x 6 columns]

# %%
Titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# Embarked       0
# dtype: int64

# %%
q=Titanic["Sex"].value_counts()
q=pd.DataFrame({"sex":q.index,"number":q.values})
q
# Out:
#    sex  number
# 0    1     266
# 1    0     152

# %%
# !pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
v=["Deceased  Male","Survived  Female"]
n=q["number"]
colors=["red","green"]
plt.gcf().set_size_inches(5, 4)
plt.pie(n,labels=v,autopct="%1.1f%%",wedgeprops={'edgecolor':'black','linewidth':3},
        colors=colors,explode=[0.1,0],startangle=240)
plt.title("percentage of gender survived")
plt.show()

# %%
Survived_pclass1=Titanic[(Titanic["Survived"]==1) & (Titanic["Pclass"]==1)]
Survived_pclass1
# Out:
#      PassengerId  Survived  Pclass  Sex   Age Embarked
# 12           904         1       1    0  23.0        S
# 14           906         1       1    0  47.0        S
# 22           914         1       1    0  30.0        S
# 24           916         1       1    0  48.0        C
# 26           918         1       1    0  22.0        C
# 44           936         1       1    0  45.0        S
# 48           940         1       1    0  60.0        C
# 53           945         1       1    0  28.0        S
# 59           951         1       1    0  36.0        C
# 69           961         1       1    0  60.0        S
# 74           966         1       1    0  35.0        C
# 77           969         1       1    0  55.0        S
# 92           984         1       1    0  27.0        S
# 96           988         1       1    0  76.0        S
# 100          992         1       1    0  43.0        C
# 112         1004         1       1    0  36.0        C
# ...

# %%
Survived_pclass2=Titanic[(Titanic["Survived"]==1) & (Titanic["Pclass"]==2)]
Survived_pclass2
# Out:
#      PassengerId  Survived  Pclass  Sex    Age Embarked
# 15           907         1       2    0  24.00        C
# 43           935         1       2    0  30.00        S
# 52           944         1       2    0  20.00        S
# 65           957         1       2    0  30.00        S
# 119         1011         1       2    0  29.00        S
# 120         1012         1       2    0  12.00        S
# 162         1054         1       2    0  26.00        S
# 175         1067         1       2    0  15.00        S
# 176         1068         1       2    0  20.00        S
# 178         1070         1       2    0  36.00        S
# 186         1078         1       2    0  21.00        S
# 203         1095         1       2    0   8.00        S
# 213         1105         1       2    0  60.00        S
# 220         1112         1       2    0  30.00        C
# 222         1114         1       2    0  22.00        S
# 238         1130         1       2    0  18.00        S
# ...

# %%
Survived_pclass3=Titanic[(Titanic["Survived"]==1) & (Titanic["Pclass"]==3)]
                                                    
Survived_pclass3
# Out:
#      PassengerId  Survived  Pclass  Sex   Age Embarked
# 1            893         1       3    0  47.0        S
# 4            896         1       3    0  22.0        S
# 6            898         1       3    0  30.0        Q
# 8            900         1       3    0  18.0        C
# 18           910         1       3    0  27.0        S
# ..           ...       ...     ...  ...   ...      ...
# 383         1275         1       3    0  19.0        S
# 408         1300         1       3    0  30.0        Q
# 409         1301         1       3    0   3.0        S
# 410         1302         1       3    0  30.0        Q
# 412         1304         1       3    0  28.0        S
#
# [72 rows x 6 columns]

# %%
g=len(Survived_pclass1)
g
# Out:
# 50

# %%
h=len(Survived_pclass2)
h
# Out:
# 30

# %%
k=len(Survived_pclass3)
k
# Out:
# 72

# %%
plt.bar(["Survived_pclass1", "Survived_pclass2", "Survived_pclass3"], [g, h, k], color="#98ff13")
plt.title("People survived in each passenger class")
plt.xlabel("Survived people")
plt.ylabel("No.of peole")
plt.ylim(0, 80)
plt.gcf().set_size_inches(5, 4.5)
plt.show()

# %%
a=Titanic["Embarked"].value_counts()
a=pd.DataFrame({"embarked":a.index,"people":a.values})
a
# Out:
#   embarked  people
# 0        S     270
# 1        C     102
# 2        Q      46

# %%
v=["S: Southampton", "C:Cherbourg", "Q: Queenstown"]
n=a["people"]
colors=["#00ffbf","#ff8000", "#d9b3ff"]
plt.gcf().set_size_inches(5, 4)
plt.pie(n,labels=v,autopct="%1.1f%%",wedgeprops={'edgecolor':'black','linewidth':3},
        colors=colors,explode=[0.1,0,0],startangle=90)
plt.title("The port where passengers boarded the Titanic")
plt.show()

# %%
Titanic
# Out:
#      PassengerId  Survived  Pclass  Sex   Age Embarked
# 0            892         0       3    1  34.5        Q
# 1            893         1       3    0  47.0        S
# 2            894         0       2    1  62.0        Q
# 3            895         0       3    1  27.0        S
# 4            896         1       3    0  22.0        S
# ..           ...       ...     ...  ...   ...      ...
# 413         1305         0       3    1  30.0        S
# 414         1306         1       1    0  39.0        C
# 415         1307         0       3    1  38.5        S
# 416         1308         0       3    1  30.0        S
# 417         1309         0       3    1  30.0        C
#
# [418 rows x 6 columns]

# %%
# Features and target variable
X = Titanic[['Pclass', 'Age', 'Sex']]
y = Titanic['Survived']

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split


# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# Initialize the Logistic Regression model
lr = LogisticRegression()

# Train the model
lr.fit(X_train, y_train)

# Make predictions
lr_pred = lr.predict(X_test)

# %%
accuracy_score(y_test, lr_pred)
# Out:
# 1.0
